# %% [markdown]
# <h3>Stp1: Install packages and load modules </h3>

# %%
#!pip install xgboost
#!pip install statistics

# %%
import xgboost as xgb
import pandas as pd
import statistics
from scipy.stats import mannwhitneyu as MUT
from scipy.stats import fisher_exact as FSH
from collections import defaultdict
import random

# %% [markdown]
# <h3>Data loading and preparation</h3>
# <p> Load the data file. the data files should be placed under <b><font color="Fuchsia" size="3" >./RBL_70_30/</font></b> refer to the notebook directory</p

# %%
dataPath = "./RBL_70_30/"
rawAccountData70 = dataPath + "raw_account_70.csv"
rawAccountData30 = dataPath + "raw_account_30.csv"
rawData70 = dataPath + "raw_data_70.csv"
rawData30 = dataPath + "raw_data_30.csv"
rawEnquiry70 = dataPath + "raw_enquiry_70.csv"
rawEnquiry30 = dataPath + "raw_enquiry_30.csv"

# %%
################################# load inside the historical data ################
df_rawAccountData70 = pd.read_csv(rawAccountData70)
df_rawAccountData30 = pd.read_csv(rawAccountData30)
df_rawData70 = pd.read_csv(rawData70)
df_rawData30 = pd.read_csv(rawData30)
df_rawEnquiry70 = pd.read_csv(rawEnquiry70)
df_rawEnquiry30 = pd.read_csv(rawEnquiry30)

# %%
frames = [df_rawAccountData30, df_rawAccountData70]
df_rawAccountData= pd.concat(frames, ignore_index=True)

frames = [df_rawData30, df_rawData70]
df_rawData= pd.concat(frames, ignore_index=True)

frames = [df_rawEnquiry30, df_rawEnquiry70]
df_rawEnquiry= pd.concat(frames, ignore_index=True)

# %%
# incase there are duplicates
#df_rawData = df_rawData.drop_duplicates(subset="apprefno", keep="last")

# %%
############################# Processing categorical data ########################
#### account data
ac_cat_cols = ["member_short_name", "acct_type", \
            "owner_indic", "writtenoffandsettled", "typeofcollateral", "paymentfrequency"]
ac_sparse2cat_cols = ["valueofcollateral", "writtenoffamounttotal", \
                   "writtenoffamountprincipal", "settlementamount", "dateofentryforcibilremarkscode"]
ac_date_cols = ["dt_opened", "upload_dt", "opened_dt", \
             "last_paymt_dt", "closed_dt", "reporting_dt", "paymt_str_dt", "paymt_end_dt"]
ac_cont_cols = ["high_credit_amt", "cur_balance_amt", "amt_past_due", \
                "creditlimit", "cashlimit", "rateofinterest", "repaymenttenure", "actualpaymentamount"]
#### enquiry data
eq_cat_cols = ["member_short_name", "enq_purpose"]
eq_date_cols = ["dt_opened", "upload_dt", "enquiry_dt"]
eq_cont_cols = ["enq_amt"]
#### current status
cu_cat_cols = ["card_name", "promo_code", "aip_status", "app_disposition", \
               "status_type", "approved_credit_limit", "intl_trn", "fee_code", "override_fee_code", \
               "override_months", "acq_source", "se_code", "lead_code", "mktg_code", "app_gender", \
               "mob_verified", "marital_status", "edu_qualification", "app_res_city", "res_type", \
               "permanent_same", "employment_type", "company_type", "industry_type", "designation", \
               "months_exp", "office_city", "id_proof", "existing_bank", "rbl_relationship_no", \
               "app_has_card", "existing_card_issuer", "app_title", "app_state", "app_existing_other_loan_cc", \
               "app_existing_rbl_cust", "app_international_transaction_fl", "app_si_ecs_flg", \
               "app_resident_india", "app_perm_state", "app_perm_city", "app_perm_country", "app_employment_type", \
               "app_office_state", "app_pref_mailing_addr", "app_go_green", "app_addon_card_dob", \
               "app_addon_card_relationship", "app_memo_status", "app_fcu_check_status", "worst_dpd6"]
cu_date_cols = ["entry_time", "cibil_datetime", "app_dob", "existing_card_start_date"]
cu_cont_cols = ["cibil_score", "num_dependents", "res_from_yr", "res_from_month", \
                "net_monthly_income", "year_joining", "years_exp", "existing_credit_limit", \
                "app_gross_monthly_income"]
cu_sparse2cat_cols = ["reject_reason_code", "reject_reason_desc", "cin", "app_coupon_code"]

# %%
def build_id_group(df, key_col, tag_col):
    id_tag = dict(zip(df[key_col], df[tag_col]))
    print id_tag.items()[0:10]
    return id_tag
################
key_col = "apprefno"
tag_col = "bad_flag_worst6"
id_tag = build_id_group(df_rawData, key_col, tag_col)
print id_tag["CCR0HH9N0"]
# Out:
# [('CC8IRED11', 0), ('CCG420NGY9', 0), ('CCI9MI20N3', 0), ('CC9A8JAR01', 0), ('CCAA446L3I', 0), ('CCMR59M7D2', 0), ('CCPAA6P348', 0), ('CC9IT6V3A', 0), ('CCDR79EW8', 0), ('CCA5I2A88A', 0)]
# 1

# %%
def random_sampler(k, lst):
    if len(lst) < k:
        return lst
    else:
        return [ lst[i] for i in sorted(random.sample(xrange(len(lst)), k)) ]

# %%
############## processing of catgorial data ################### --only for binary
def extracte_historical_cat_and_ft_sele(df, cols, key_col, min_num, id_tag, critical_val, suf):
    id_cat_fq = defaultdict(lambda:defaultdict(int))
    cat_ids = defaultdict(set)
    num_rcds = len(df[df.keys()[0]])
    pfids = set()
    err_ct = 0
    for i in range(num_rcds):
        uid = df[key_col][i]
        try:
            pfids.add(str(uid))
        except:
            print uid, type(uid), "[" + uid + "]", i
            err_ct += 1
            if err_ct > 50:
                return
            continue
        for col in cols: 
            val = df[col][i]
            if val == None:
                continue
            cat_key = suf + "@#_" + col + "@#" + str(val)
            id_cat_fq[uid][cat_key] += 1
            cat_ids[cat_key].add(uid)
    print "toal categoricals to be scanned: ", len(cat_ids)
    uids = list(pfids)
    ########## discard sparse data and non-onformatie features ############
    cats_keep = set()
    for cat in cat_ids:
        if len(cat_ids[cat]) < min_num:
            print "Skip\t[" + cat + "]", len(cat_ids[cat])
            continue
        o_vals = []
        z_vals = []
        for uid in uids:
            if uid not in id_tag:
                continue
            tag = id_tag[uid]
            if tag not in [0,1]:
                continue
            if tag == 1:
                o_vals.append(id_cat_fq[uid][cat])
            else:
                z_vals.append(id_cat_fq[uid][cat])
        if min(len(z_vals), len(o_vals)) < min_num:
            continue
        try:
            v, p = MUT(random_sampler(200, o_vals), random_sampler(200, z_vals))
        except:
            continue
        #print v, p, cat
        if p <= critical_val:
            print "Catgorical\t[" + cat + "] is informative: p =", p, ">>", len(z_vals), len(o_vals)
            cats_keep.add(cat)
    print "total kept categories", len(cats_keep)
    col_dic = defaultdict(list)
    
    col_dic["userid"] = uids
    
    for cat in cats_keep:
        temp = []
        for uid in uids:
            temp.append(id_cat_fq[uid][cat])
        col_dic[cat] = temp
    return col_dic

# %%
key_col = "apprefno"
min_num = 20
critical_val = 0.05

# %%
suf = "acc"
ac_cat_colDic = extracte_historical_cat_and_ft_sele(df_rawAccountData, ac_cat_cols, key_col, \
                                                 min_num, id_tag, critical_val, suf)
# Out:
# toal categoricals to be scanned:  60
# Skip	[acc@#_acct_type@#16] 1
# Skip	[acc@#_writtenoffandsettled@#99.0] 8
# Catgorical	[acc@#_typeofcollateral@#nan] is informative: p = 0.0172227330655 >> 32670 1466
# Skip	[acc@#_writtenoffandsettled@#7.0] 2
# Catgorical	[acc@#_paymentfrequency@#nan] is informative: p = 2.64572202481e-06 >> 32670 1466
# Skip	[acc@#_acct_type@#33] 7
# Skip	[acc@#_acct_type@#34] 14
# Skip	[acc@#_acct_type@#36] 1
# Catgorical	[acc@#_acct_type@#10] is informative: p = 2.29461126791e-05 >> 32670 1466
# Skip	[acc@#_acct_type@#11] 6
# Skip	[acc@#_member_short_name@#RBL BANK] 3
# Skip	[acc@#_acct_type@#14] 8
# Catgorical	[acc@#_acct_type@#15] is informative: p = 0.0282005062764 >> 32670 1466
# Skip	[acc@#_acct_type@#56] 11
# Skip	[acc@#_acct_type@#57] 1
# Catgorical	[acc@#_acct_type@#54] is informative: p = 0.0415031306076 >> 32670 1466
# Catgorical	[acc@#_writtenoffandsettled@#nan] is informative: p = 2.97766502549e-05 >> 32670 1466
# Skip	[acc@#_typeofcollateral@#3.0] 19
# Skip	[acc@#_member_short_name@#RBL Bank] 19
# Catgorical	[acc@#_member_short_name@#NOT DISCLOSED] is informative: p = 0.000555303012687 >> 32670 1466
# Catgorical	[acc@#_owner_indic@#1] is informative: p = 0.00105491134844 >> 32670 1466
# Catgorical	[acc@#_paymentfrequency@#3.0] is informative: p = 0.0234327574077 >> 32670 1466
# Skip	[acc@#_paymentfrequency@#4.0] 2
# total kept categories 9

# %%
suf = "enq"
eq_cat_colDic = extracte_historical_cat_and_ft_sele(df_rawEnquiry, eq_cat_cols, key_col, \
                                                 min_num, id_tag, critical_val, suf)
# Out:
# toal categoricals to be scanned:  43
# Skip	[enq@#_enq_purpose@#57.0] 9
# Skip	[enq@#_enq_purpose@#11.0] 15
# Catgorical	[enq@#_enq_purpose@#10.0] is informative: p = 0.04077124042 >> 32670 1466
# Skip	[enq@#_enq_purpose@#55.0] 12
# Skip	[enq@#_enq_purpose@#43.0] 6
# Catgorical	[enq@#_enq_purpose@#6.0] is informative: p = 0.00557135585207 >> 32670 1466
# Skip	[enq@#_enq_purpose@#42.0] 3
# Skip	[enq@#_enq_purpose@#58.0] 8
# Catgorical	[enq@#_enq_purpose@#5.0] is informative: p = 0.00621609100297 >> 32670 1466
# Skip	[enq@#_enq_purpose@#41.0] 12
# Catgorical	[enq@#_enq_purpose@#32.0] is informative: p = 0.0415031306076 >> 32670 1466
# Skip	[enq@#_enq_purpose@#31.0] 6
# Skip	[enq@#_enq_purpose@#59.0] 13
# Catgorical	[enq@#_enq_purpose@#7.0] is informative: p = 0.0275949746691 >> 32670 1466
# Skip	[enq@#_enq_purpose@#56.0] 17
# Skip	[enq@#_enq_purpose@#36.0] 7
# Skip	[enq@#_enq_purpose@#33.0] 18
# Skip	[enq@#_enq_purpose@#16.0] 2
# Skip	[enq@#_enq_purpose@#34.0] 5
# Skip	[enq@#_enq_purpose@#15.0] 14
# total kept categories 5

# %%
########################## continus data historical: counts min max median #####################
def extracte_historical_val(df, cols, key_col, min_num, id_tag, critical_val, suf):
    id_col_vals = defaultdict(lambda:defaultdict(list))
    
    col_ids = defaultdict(set)
    num_rcds = len(df[df.keys()[0]])
    pfids = set()
    
    for i in range(num_rcds):
        uid = df[key_col][i]
        try:
            pfids.add(uid)
        except:
            print uid
            return
        for col in cols:
            if pd.isnull(df[col][i]):
                continue
            try:
                val = float(str(df[col][i]).replace("\"", ""))
            except:
                print df[col][i], col
                return None
            id_col_vals[uid][col].append(val)
            col_ids[col].add(uid)
    
    uids = list(pfids)
    ########## discard minor features ############
    col_keep = set()
    for col in col_ids:
        if len(col_ids[col]) < min_num:
            print "Skip\t[" + col + "]", len(col_ids[col])
            continue
        col_keep.add(col)
    print "total kept categories at stage 1", len(col_keep)
    col_dic = defaultdict(list)
    col_dic["userid"] = uids
    keep_ct = 0
    for col in col_keep:
        temp_max = []
        temp_min = []
        temp_med = []
        temp_cnt = []
        for uid in uids:
            vals = id_col_vals[uid][col]
            if len(vals) == 0:
                minv = -99
                maxv = -99
                medv = -99
                ct = 0
            else:
                minv = min(vals)
                maxv = max(vals)
                medv = statistics.median(vals)
                ct = len(vals)
            temp_max.append(maxv)
            temp_min.append(minv)
            temp_med.append(medv)
            temp_cnt.append(ct)
        #------------ test
        max_o_vals = []
        max_z_vals = []
        min_o_vals = []
        min_z_vals = []
        med_o_vals = []
        med_z_vals = []
        cnt_o_vals = []
        cnt_z_vals = []
        for i, uid in enumerate(uids):
            if uid not in id_tag:
                continue
            tag = id_tag[uid]
            if tag not in [0, 1]:
                continue
            if tag == 1:
                max_o_vals.append(temp_max[i])
                min_o_vals.append(temp_min[i])
                med_o_vals.append(temp_med[i])
                cnt_o_vals.append(temp_cnt[i])    
            else:
                max_z_vals.append(temp_max[i])
                min_z_vals.append(temp_min[i])
                med_z_vals.append(temp_med[i])
                cnt_z_vals.append(temp_cnt[i])
        
        v, p = MUT(random_sampler(200, max_o_vals), random_sampler(100, max_z_vals))
        if p <= critical_val:
            col_str = suf + "@#_" + col +"_max"
            col_dic[col_str] = temp_max
            keep_ct += 1
            print "Continous\t[" + col_str + "] is informative: p =", p
        v, p = MUT(random_sampler(200, min_o_vals), random_sampler(100, min_z_vals))
        if p <= critical_val:
            col_str = suf + "@#_" + col +"_min"
            col_dic[col_str] = temp_min
            keep_ct += 1
            print "Continous\t[" + col_str + "] is informative: p =", p
        v, p = MUT(random_sampler(200, med_o_vals), random_sampler(100, med_z_vals))
        if p <= critical_val:
            col_str = suf + "@#_" + col +"_med"
            col_dic[col_str] = temp_med
            keep_ct += 1
            print "Continous\t[" + col_str + "] is informative: p =", p
        v, p = MUT(random_sampler(200, cnt_o_vals), random_sampler(100, cnt_z_vals))
        if p <= critical_val:
            col_str = suf + "@#_" + col +"_cnt"
            col_dic[col_str] = temp_cnt
            keep_ct += 1
            print "Continous\t[" + col_str + "] is informative: p =", p
    print "total kept features:", keep_ct
    return col_dic
################################

# %%
suf = "acc"
ac_cnt_colDic = extracte_historical_val(df_rawAccountData, ac_cont_cols, \
                                        key_col, min_num, id_tag, critical_val, suf)
# Out:
# total kept categories at stage 1 8
# Continous	[acc@#_rateofinterest_cnt] is informative: p = 0.0351814712458
# Continous	[acc@#_amt_past_due_cnt] is informative: p = 0.0158650587972
# Continous	[acc@#_cashlimit_med] is informative: p = 0.0399023899025
# Continous	[acc@#_cashlimit_cnt] is informative: p = 0.00110861883824
# Continous	[acc@#_creditlimit_max] is informative: p = 0.00038054695492
# Continous	[acc@#_creditlimit_min] is informative: p = 0.0245892223653
# Continous	[acc@#_creditlimit_cnt] is informative: p = 0.0127109555915
# Continous	[acc@#_actualpaymentamount_med] is informative: p = 0.0253313925375
# total kept features: 8

# %%
suf = "enq"
eq_cnt_colDic = extracte_historical_val(df_rawEnquiry, eq_cont_cols, key_col, min_num, id_tag, critical_val, suf)
# Out:
# total kept categories at stage 1 1
# total kept features: 0

# %%
def convert_to_dates(raw_date_str, refer_date):
    try:
        comp = raw_date_str.split("-")
        date_str = "".join(comp[0:2]) + "20" + comp[2]
        date = pd.to_datetime(date_str, format = "%d%b%Y")
        return (date - refer_date).days
    except:
        return None

# %%
def is_informative(uids, vals, refs, id_tags, critical_val, col_str):
    try:
        o_vals = []
        z_vals = []
        for i, uid in enumerate(uids):
            if refs[i] > 99998:
                continue
            tag = id_tags[uid]
            if tag not in [1, 0]:
                continue
            if tag == 1:
                o_vals.append(vals[i])
            else:
                z_vals.append(vals[i])
        v, p = MUT(random_sampler(200, o_vals), random_sampler(200, z_vals))
        if p <= critical_val:
            print "data_field\t[" + col_str + "] is informative: p =", p
            return True
        else:
            return False  
    except:
        return False

# %%
def time_interval(df, col_key, time_cols, critical_val, id_tags, suf):
    num_rcds = len(df[col_key])
    print "number of records:", num_rcds
    print "num_cols to be processed:", len(time_cols)
    refer_date = pd.to_datetime("1 1 2014", format = "%d %m %Y")
    uidst = set()
    for i in range(num_rcds):
        uidst.add(df[col_key][i])
    uids = list(uidst)
    print "Number of uids:", len(uids)
    colDict = defaultdict(list)
    num_kp = 0
    colDict["userid"] = uids
    
    for time_col in time_cols:
        print "processing>", time_col
        uid_days = defaultdict(list)
        for i in range(num_rcds):
            if i % 50000 == 0:
                print i
            date_str = df[time_col][i]
            days = convert_to_dates(date_str, refer_date) # can be none
            if days == None:
                continue
            uid = df[col_key][i]
            uid_days[uid].append(days)
        
        #print uid_days.items()[0:10]
        
        print "stag1.....on", len(uids), "users"
        ############ get earliest, latest time, min, max, median, intervals, counts, density ###########
        maxItvs = []
        minItvs = []
        medItvs = []
        starts = []
        ends = []
        cts = []
        denss = []
        count = 0
        for uid in uids:
            if count%5000 == 0:
                print count
            #if count > 10:
            #    return None
            count += 1
            if len(uid_days[uid]) <= 1:
                start = 0
                en = 99999
                ct = 1
                maxItv = 99999 - start
                minItv = 99999 - start
                medItv = 99999 - start
                dens = 1.0/max(float(en - start), 1)
                #print "--1"
            else:
                #print "----2"
                tms = sorted(uid_days[uid])
                start = tms[0]
                en = tms[-1]
                ct = len(tms)
                itvs = []
                for i in range(1, ct):
                    itvs.append(tms[i] - tms[i-1])
                maxItv = max(itvs)
                minItv = min(itvs)
                medItv = statistics.median(itvs)
                dens = float(ct)/max(float(en - start), 1)
                #print "--2"
            #print maxItv, minItv, minItv, medItv, start, en, ct, dens
            maxItvs.append(maxItv)
            minItvs.append(minItv)
            medItvs.append(medItv)
            starts.append(start)
            ends.append(en)
            cts.append(ct)
            denss.append(dens)
            #if count > 4:
                #break
        #break
        print "stg2...."
        col_str = suf + "@#_" + time_col + "@#maxItv"
        if is_informative(uids, maxItvs, maxItvs, id_tags, critical_val, col_str):
            colDict[col_str] = maxItvs
            num_kp += 1
        
        col_str = suf + "@#_" + time_col + "@#minItv"
        if is_informative(uids, minItvs, maxItvs, id_tags, critical_val, col_str):
            colDict[col_str] = minItvs
            num_kp += 1
        
        col_str = suf + "@#_" + time_col + "@#medItv"
        if is_informative(uids, medItvs, maxItvs, id_tags, critical_val, col_str):
            colDict[col_str] = medItvs
            num_kp += 1
            
        col_str = suf + "@#_" + time_col + "@#counts"
        if is_informative(uids, cts, maxItvs, id_tags, critical_val, col_str):
            colDict[col_str] = cts
            num_kp += 1
            #print cts[0:20]
            #return None
            
        col_str = suf + "@#_" + time_col + "@#dens"
        if is_informative(uids, denss, maxItvs, id_tags, critical_val, col_str):
            colDict[col_str] = denss
            num_kp += 1
            
        col_str = suf + "@#_" + time_col + "@#starts"
        if is_informative(uids, starts, maxItvs, id_tags, critical_val, col_str):
            colDict[col_str] = starts
            num_kp += 1
        
        col_str = suf + "@#_" + time_col + "@#ends"
        if is_informative(uids, ends, maxItvs, id_tags, critical_val, col_str):
            colDict[col_str] = ends
            num_kp += 1    
        #################
        
    print "Total kept features:", num_kp    
    return colDict
#####################
suf = "acc"
ac_dateColDict = time_interval(df_rawAccountData, key_col, ac_date_cols, critical_val, id_tag, suf)
# Out:
# number of records: 265897
# num_cols to be processed: 8
# Number of uids: 34136
# processing> dt_opened
# 0
# 50000
# 100000
# 150000
# 200000
# 250000
# stag1.....on 34136 users
# 0
# 5000
# 10000
# 15000
# 20000
# 25000
# 30000
# stg2....
# data_field	[acc@#_dt_opened@#counts] is informative: p = 0.0249157150163
# data_field	[acc@#_dt_opened@#dens] is informative: p = 0.000516268226839
# processing> upload_dt
# 0
# 50000
# 100000
# 150000
# 200000
# 250000
# stag1.....on 34136 users
# 0
# 5000
# 10000
# 15000
# 20000
# 25000
# 30000
# stg2....
# data_field	[acc@#_upload_dt@#counts] is informative: p = 0.000965005025269
# data_field	[acc@#_upload_dt@#dens] is informative: p = 0.0327416931624
# processing> opened_dt
# 0
# 50000
# 100000
# 150000
# 200000
# 250000
# stag1.....on 34136 users
# 0
# 5000
# 10000
# 15000
# 20000
# 25000
# 30000
# stg2....
# data_field	[acc@#_opened_dt@#minItv] is informative: p = 0.0010224646792
# data_field	[acc@#_opened_dt@#medItv] is informative: p = 0.0160598715249
# data_field	[acc@#_opened_dt@#counts] is informative: p = 0.0060898082843
# data_field	[acc@#_opened_dt@#dens] is informative: p = 0.0234973994893
# processing> last_paymt_dt
# 0
# 50000
# 100000
# 150000
# 200000
# 250000
# stag1.....on 34136 users
# 0
# 5000
# 10000
# 15000
# 20000
# 25000
# 30000
# stg2....
# data_field	[acc@#_last_paymt_dt@#minItv] is informative: p = 0.000885172777521
# data_field	[acc@#_last_paymt_dt@#ends] is informative: p = 0.00977191422798
# processing> closed_dt
# 0
# 50000
# 100000
# 150000
# 200000
# 250000
# stag1.....on 34136 users
# 0
# 5000
# 10000
# 15000
# 20000
# 25000
# 30000
# stg2....
# processing> reporting_dt
# 0
# 50000
# 100000
# 150000
# 200000
# 250000
# stag1.....on 34136 users
# 0
# 5000
# 10000
# 15000
# 20000
# 25000
# 30000
# stg2....
# data_field	[acc@#_reporting_dt@#minItv] is informative: p = 0.0148106730676
# data_field	[acc@#_reporting_dt@#counts] is informative: p = 0.0328163120136
# processing> paymt_str_dt
# 0
# 50000
# 100000
# 150000
# 200000
# 250000
# stag1.....on 34136 users
# 0
# 5000
# 10000
# 15000
# 20000
# 25000
# 30000
# stg2....
# processing> paymt_end_dt
# 0
# 50000
# 100000
# 150000
# 200000
# 250000
# stag1.....on 34136 users
# 0
# 5000
# 10000
# 15000
# 20000
# 25000
# 30000
# stg2....
# data_field	[acc@#_paymt_end_dt@#maxItv] is informative: p = 0.0416585016791
# data_field	[acc@#_paymt_end_dt@#counts] is informative: p = 0.000280503224214
# data_field	[acc@#_paymt_end_dt@#ends] is informative: p = 0.00295500869129
# Total kept features: 15

# %%
print ac_dateColDict.keys()
# Out:
# ['acc@#_upload_dt@#dens', 'acc@#_upload_dt@#counts', 'acc@#_dt_opened@#counts', 'acc@#_opened_dt@#counts', 'acc@#_paymt_end_dt@#counts', 'userid', 'acc@#_opened_dt@#minItv', 'acc@#_last_paymt_dt@#minItv', 'acc@#_opened_dt@#medItv', 'acc@#_dt_opened@#dens', 'acc@#_paymt_end_dt@#maxItv', 'acc@#_paymt_end_dt@#ends', 'acc@#_reporting_dt@#minItv', 'acc@#_last_paymt_dt@#ends', 'acc@#_reporting_dt@#counts', 'acc@#_opened_dt@#dens']

# %%
suf = "enq"
eq_dateColDict = time_interval(df_rawEnquiry, key_col, eq_date_cols, critical_val, id_tag, suf)
# Out:
# number of records: 586687
# num_cols to be processed: 3
# Number of uids: 34136
# processing> dt_opened
# 0
# 50000
# 100000
# 150000
# 200000
# 250000
# 300000
# 350000
# 400000
# 450000
# 500000
# 550000
# stag1.....on 34136 users
# 0
# 5000
# 10000
# 15000
# 20000
# 25000
# 30000
# stg2....
# processing> upload_dt
# 0
# 50000
# 100000
# 150000
# 200000
# 250000
# 300000
# 350000
# 400000
# 450000
# 500000
# 550000
# stag1.....on 34136 users
# 0
# 5000
# 10000
# 15000
# 20000
# 25000
# 30000
# stg2....
# data_field	[enq@#_upload_dt@#counts] is informative: p = 0.00367716414159
# processing> enquiry_dt
# 0
# 50000
# 100000
# 150000
# 200000
# 250000
# 300000
# 350000
# 400000
# 450000
# 500000
# 550000
# stag1.....on 34136 users
# 0
# 5000
# 10000
# 15000
# 20000
# 25000
# 30000
# stg2....
# data_field	[enq@#_enquiry_dt@#maxItv] is informative: p = 0.00475556469847
# data_field	[enq@#_enquiry_dt@#dens] is informative: p = 0.0169673870221
# data_field	[enq@#_enquiry_dt@#starts] is informative: p = 0.0427999544812
# data_field	[enq@#_enquiry_dt@#ends] is informative: p = 0.00321879796029
# Total kept features: 5

# %%
######################  none aggregated convertion and feture selection ################

# %%
def is_informative2(uids, vals, id_tags, critical_val, col_str):
    o_vals = []
    z_vals = []
    for i, uid in enumerate(uids):
        if vals[i] == None:
            continue
        tag = id_tags[uid]
        if tag not in [1, 0]:
            continue
        if tag == 1:
            o_vals.append(vals[i])
        else:
            z_vals.append(vals[i])
    v, p = MUT(random_sampler(200, o_vals), random_sampler(200, z_vals))
    if p <= critical_val:
        print "date_field\t[" + col_str + "] is informative: p =", p
        return True
    else:
        return False

# %%
#df_rawData70
def convert_date_to_relative_and_ft_selection(df, col_key, time_cols, critical_val, id_tags, suf):
    num_rcds = len(df[col_key])
    print "number of records:", num_rcds
    print "num_cols to be processed:", len(time_cols)
    refer_date = pd.to_datetime("1 1 2014", format = "%d %m %Y")
    uidst = set()
    for i in range(num_rcds):
        uidst.add(df[col_key][i])
    uids = list(uidst)
    print "Number of uids:", len(uids)
    colDict = defaultdict(list)
    num_kp = 0
    colDict["userid"] = uids
    
    for time_col in time_cols:
        print "processing>", time_col
        uid_days = defaultdict(int)
        for i in range(num_rcds):
            if i % 50000 == 0:
                print i
            date_str = df[time_col][i]
            days = convert_to_dates(date_str, refer_date) # can be none
            #if days == None:
            #    continue
            uid = df[col_key][i]
            uid_days[uid] = days

        print "stg1...."
        col_str = suf + "@#_" + time_col + "@#_rela"
        if is_informative2(uids, df[time_col], id_tags, critical_val, col_str):
            daysl = []
            for uid in uids:
                if uid not in uid_days:
                    daysl.append(None)
                else:
                    daysl.append(uid_days[uid])
            colDict[col_str] = daysl
            num_kp += 1
        #################
        
    print "Total kept features:", num_kp    
    return colDict
#####################
suf = "cur"
cu_dateColDict = convert_date_to_relative_and_ft_selection(df_rawData, key_col, cu_date_cols, \
                                                           critical_val, id_tag, suf)
# Out:
# number of records: 34136
# num_cols to be processed: 4
# Number of uids: 34136
# processing> entry_time
# 0
# stg1....
# processing> cibil_datetime
# 0
# stg1....
# processing> app_dob
# 0
# stg1....
# processing> existing_card_start_date
# 0
# stg1....
# Total kept features: 0

# %%
def is_informative_fisher(uids, vals, id_tags, critical_val, col_str):
    cat_zo_ct = defaultdict(lambda: defaultdict(int))
    for i, uid in enumerate(uids):
        if vals[i] == None:
            continue
        cat = vals[i]
        tag = id_tags[uid]
        if (tag not in [1, 0]) or (cat not in [1, 0]):
            continue
        cat_zo_ct[cat][tag] += 1
        
    bg = [cat_zo_ct[0][0], cat_zo_ct[0][1]]
    cat = [cat_zo_ct[1][0], cat_zo_ct[1][1]]
    #try:
    print ">>", bg, cat
    v, p = FSH([bg, cat])
    if p <= critical_val:
        print cat, "of date_field\t[" + col_str + "] is informative: p =", p
        return True
    else:
        return False
    #except:
    #    print "Warning: data error"
    #    return False

# %%
def non_agg_cat_processing(df, col_key, cat_cols, critical_val, id_tags, min_sz, suf):
    num_rcds = len(df[col_key])
    print "number of records:", num_rcds
    print "num_cols to be processed:", len(cat_cols)
    uidst = set()
    for i in range(num_rcds):
        uidst.add(df[col_key][i])
    uids = list(uidst)
    print "Number of uids:", len(uids)
    colDict = defaultdict(list)
    num_kp = 0
    colDict["userid"] = uids
    
    uid_cat_val = defaultdict(lambda: defaultdict(int))
    print "#### stage 1 #################"
    cat_ct = defaultdict(int)
    for i in range(num_rcds):
        if i % 50000 == 0:
            print i
        uid = df[col_key][i]
        for cat_col in cat_cols:
            if df[cat_col][i] != None:
                cat = suf + "@#_" + cat_col + "@#" + str(df[cat_col][i])
                uid_cat_val[uid][cat] = 1
                cat_ct[cat] += 1
    print "#### stage 2 #################"
    for cat in cat_ct:
        if cat_ct[cat] < min_sz:
            continue
        print "processing>", cat
        vals = []
        for uid in uids:
            val = uid_cat_val[uid][cat]
            vals.append(val)
            
        if is_informative_fisher(uids, vals, id_tags, critical_val, cat):
            colDict[cat] = vals
            num_kp += 1
        ##############
        
    print "Total kept features:", num_kp    
    return colDict
#####################
suf = "cur"
cu_catColDict = non_agg_cat_processing(df_rawData, key_col, cu_cat_cols, critical_val, id_tag, 100, suf)
# Out:
# number of records: 34136
# num_cols to be processed: 51
# Number of uids: 34136
# #### stage 1 #################
# 0
# #### stage 2 #################
# processing> cur@#_approved_credit_limit@#70000.0
# >> [32433, 1453] [237, 13]
# processing> cur@#_res_type@#Self
# >> [17909, 824] [14761, 642]
# processing> cur@#_approved_credit_limit@#71000.0
# >> [32447, 1449] [223, 17]
# processing> cur@#_edu_qualification@#Diploma
# >> [32365, 1457] [305, 9]
# processing> cur@#_acq_source@#SARE
# >> [31847, 1413] [823, 53]
# [823, 53] of date_field	[cur@#_acq_source@#SARE] is informative: p = 0.0139430038332
# processing> cur@#_existing_bank@#State Bank of India
# >> [32140, 1445] [530, 21]
# processing> cur@#_approved_credit_limit@#126000.0
# >> [32356, 1454] [314, 12]
# processing> cur@#_existing_bank@#Punjab National Bank
# >> [32550, 1463] [120, 3]
# processing> cur@#_se_code@#HA01
# >> [32538, 1461] [132, 5]
# processing> cur@#_acq_source@#MA14
# >> [32529, 1452] [141, 14]
# [141, 14] of date_field	[cur@#_acq_source@#MA14] is informative: p = 0.00819643039219
# processing> cur@#_approved_credit_limit@#131000.0
# >> [32494, 1459] [176, 7]
# processing> cur@#_approved_credit_limit@#110000.0
# >> [32394, 1455] [276, 11]
# processing> cur@#_se_code@#G007
# >> [32515, 1458] [155, 8]
# processing> cur@#_se_code@#G009
# >> [31598, 1417] [1072, 49]
# processing> cur@#_override_months@#0.0
# >> [25442, 1168] [7228, 298]
# processing> cur@#_approved_credit_limit@#75000.0
# >> [32411, 1447] [259, 19]
# processing> cur@#_app_res_city@#Bengaluru
# >> [31943, 1421] [727, 45]
# [727, 45] of date_field	[cur@#_app_res_city@#Bengaluru] is informative: p = 0.038498517236
# processing> cur@#_approved_credit_limit@#111000.0
# >> [32421, 1454] [249, 12]
# processing> cur@#_res_type@#Paren
# >> [24219, 1083] [8451, 383]
# processing> cur@#_approved_credit_limit@#140000.0
# >> [32491, 1464] [179, 2]
# [179, 2] of date_field	[cur@#_approved_credit_limit@#140000.0] is informative: p = 0.0263343978958
# processing> cur@#_app_perm_city@#494.0
# >> [32565, 1464] [105, 2]
# processing> cur@#_app_state@#2.0
# >> [29379, 1342] [3291, 124]
# [3291, 124] of date_field	[cur@#_app_state@#2.0] is informative: p = 0.0451611239937
# processing> cur@#_approved_credit_limit@#74000.0
# >> [32496, 1455] [174, 11]
# processing> cur@#_app_res_city@#Ghaziabad
# >> [30716, 1396] [1954, 70]
# processing> cur@#_app_perm_city@#144.0
# >> [32565, 1464] [105, 2]
# processing> cur@#_se_code@#AS19
# >> [30803, 1380] [1867, 86]
# processing> cur@#_se_code@#AS18
# >> [32392, 1461] [278, 5]
# [278, 5] of date_field	[cur@#_se_code@#AS18] is informative: p = 0.0372200432588
# processing> cur@#_se_code@#AS11
# >> [31843, 1449] [827, 17]
# [827, 17] of date_field	[cur@#_se_code@#AS11] is informative: p = 0.000392726424071
# processing> cur@#_se_code@#AS17
# >> [30999, 1381] [1671, 85]
# processing> cur@#_se_code@#AS16
# >> [30933, 1394] [1737, 72]
# processing> cur@#_se_code@#AS15
# >> [32064, 1451] [606, 15]
# [606, 15] of date_field	[cur@#_se_code@#AS15] is informative: p = 0.0162572736452
# processing> cur@#_approved_credit_limit@#56000.0
# >> [32449, 1442] [221, 24]
# [221, 24] of date_field	[cur@#_approved_credit_limit@#56000.0] is informative: p = 0.000180290933845
# processing> cur@#_fee_code@#PD1
# >> [20976, 1021] [11694, 445]
# [11694, 445] of date_field	[cur@#_fee_code@#PD1] is informative: p = 1.73154514733e-05
# processing> cur@#_industry_type@#Industrial
# >> [32349, 1456] [321, 10]
# processing> cur@#_promo_code@#VNDX
# >> [32037, 1440] [633, 26]
# processing> cur@#_industry_type@#Manufacturing
# >> [32565, 1462] [105, 4]
# processing> cur@#_res_type@#Rente
# >> [23505, 1038] [9165, 428]
# processing> cur@#_se_code@#IC01
# >> [32143, 1430] [527, 36]
# [527, 36] of date_field	[cur@#_se_code@#IC01] is informative: p = 0.0203033471068
# processing> cur@#_app_perm_city@#835.0
# >> [32559, 1464] [111, 2]
# processing> cur@#_app_perm_city@#15.0
# >> [31145, 1407] [1525, 59]
# processing> cur@#_approved_credit_limit@#145000.0
# >> [32563, 1461] [107, 5]
# processing> cur@#_app_perm_city@#75.0
# >> [32542, 1465] [128, 1]
# [128, 1] of date_field	[cur@#_app_perm_city@#75.0] is informative: p = 0.04676718173
# processing> cur@#_approved_credit_limit@#121000.0
# >> [32464, 1456] [206, 10]
# processing> cur@#_se_code@#AS34
# >> [31459, 1420] [1211, 46]
# processing> cur@#_se_code@#AS31
# >> [32574, 1460] [96, 6]
# processing> cur@#_se_code@#AS33
# >> [31650, 1407] [1020, 59]
# processing> cur@#_se_code@#AS32
# >> [31548, 1419] [1122, 47]
# processing> cur@#_industry_type@#nan
# >> [24945, 1061] [7725, 405]
# [7725, 405] of date_field	[cur@#_industry_type@#nan] is informative: p = 0.000562408746371
# processing> cur@#_acq_source@#BBOL
# >> [32397, 1458] [273, 8]
# processing> cur@#_approved_credit_limit@#102000.0
# >> [32381, 1461] [289, 5]
# [289, 5] of date_field	[cur@#_approved_credit_limit@#102000.0] is informative: p = 0.0283851571891
# processing> cur@#_existing_card_issuer@#State Bank of India
# >> [28941, 1356] [3729, 110]
# [3729, 110] of date_field	[cur@#_existing_card_issuer@#State Bank of India] is informative: p = 1.36389975694e-06
# processing> cur@#_fee_code@#PB1
# >> [32368, 1456] [302, 10]
# processing> cur@#_card_name@#Platinum Maxima
# >> [20439, 794] [12231, 672]
# [12231, 672] of date_field	[cur@#_card_name@#Platinum Maxima] is informative: p = 1.54401867563e-10
# processing> cur@#_approved_credit_limit@#146000.0
# >> [32504, 1463] [166, 3]
# processing> cur@#_approved_credit_limit@#103000.0
# >> [32425, 1457] [245, 9]
# processing> cur@#_office_city@#Gurgaon
# >> [27842, 1214] [4828, 252]
# [4828, 252] of date_field	[cur@#_office_city@#Gurgaon] is informative: p = 0.0132441866918
# processing> cur@#_existing_bank@#The Ratnakar Bank Ltd.
# >> [32039, 1456] [631, 10]
# [631, 10] of date_field	[cur@#_existing_bank@#The Ratnakar Bank Ltd.] is informative: p = 0.000161440021653
# processing> cur@#_override_fee_code@#nan
# >> [15052, 562] [17618, 904]
# [17618, 904] of date_field	[cur@#_override_fee_code@#nan] is informative: p = 5.72885298895e-09
# processing> cur@#_app_res_city@#Rangareddy
# >> [32391, 1452] [279, 14]
# processing> cur@#_approved_credit_limit@#84000.0
# >> [32400, 1458] [270, 8]
# processing> cur@#_industry_type@#Information Technology
# >> [31656, 1419] [1014, 47]
# processing> cur@#_id_proof@#Voter ID
# >> [32488, 1461] [182, 5]
# processing> cur@#_app_perm_state@#31.0
# >> [32055, 1453] [615, 13]
# [615, 13] of date_field	[cur@#_app_perm_state@#31.0] is informative: p = 0.00373328709665
# processing> cur@#_approved_credit_limit@#49000.0
# >> [32571, 1459] [99, 7]
# processing> cur@#_approved_credit_limit@#130000.0
# >> [32346, 1450] [324, 16]
# processing> cur@#_existing_bank@#Kotak Mahindra Bank Ltd.
# >> [32397, 1450] [273, 16]
# processing> cur@#_designation@#SR ASSOCIATE
# >> [32547, 1460] [123, 6]
# processing> cur@#_approved_credit_limit@#94000.0
# >> [32371, 1451] [299, 15]
# processing> cur@#_app_state@#21.0
# >> [29802, 1350] [2868, 116]
# processing> cur@#_approved_credit_limit@#85000.0
# >> [32462, 1454] [208, 12]
# processing> cur@#_approved_credit_limit@#45000.0
# >> [32568, 1459] [102, 7]
# processing> cur@#_se_code@#3056
# >> [32500, 1460] [170, 6]
# processing> cur@#_app_perm_state@#16.0
# >> [32466, 1458] [204, 8]
# processing> cur@#_app_fcu_check_status@#N
# >> [34, 1] [32636, 1465]
# processing> cur@#_app_existing_rbl_cust@#Y
# >> [32039, 1456] [631, 10]
# [631, 10] of date_field	[cur@#_app_existing_rbl_cust@#Y] is informative: p = 0.000161440021653
# processing> cur@#_existing_bank@#HDFC Bank
# >> [30844, 1366] [1826, 100]
# [1826, 100] of date_field	[cur@#_existing_bank@#HDFC Bank] is informative: p = 0.049019255313
# processing> cur@#_marital_status@#1.0
# >> [7558, 400] [25112, 1066]
# [25112, 1066] of date_field	[cur@#_marital_status@#1.0] is informative: p = 0.000315432402855
# processing> cur@#_mob_verified@#Y
# >> [29541, 1286] [3129, 180]
# [3129, 180] of date_field	[cur@#_mob_verified@#Y] is informative: p = 0.000969758387342
# processing> cur@#_designation@#CONSULTANT
# >> [32563, 1460] [107, 6]
# processing> cur@#_approved_credit_limit@#132000.0
# >> [32459, 1454] [211, 12]
# processing> cur@#_app_perm_city@#16.0
# >> [32334, 1449] [336, 17]
# processing> cur@#_approved_credit_limit@#68000.0
# >> [32347, 1447] [323, 19]
# processing> cur@#_existing_bank@#IDBI Bank Ltd.
# >> [32536, 1458] [134, 8]
# processing> cur@#_acq_source@#PBOL
# >> [32561, 1462] [109, 4]
# processing> cur@#_se_code@#VA02
# >> [32403, 1458] [267, 8]
# processing> cur@#_approved_credit_limit@#61000.0
# >> [32440, 1449] [230, 17]
# processing> cur@#_industry_type@#KPO/LPO/ITES
# >> [32378, 1457] [292, 9]
# processing> cur@#_app_go_green@#N
# >> [31554, 1401] [1116, 65]
# [1116, 65] of date_field	[cur@#_app_go_green@#N] is informative: p = 0.0406505117244
# processing> cur@#_app_go_green@#Y
# >> [29753, 1345] [2917, 121]
# processing> cur@#_se_code@#VRP4
# >> [32511, 1460] [159, 6]
# processing> cur@#_se_code@#VRP1
# >> [32465, 1455] [205, 11]
# processing> cur@#_se_code@#VRP2
# >> [32511, 1461] [159, 5]
# processing> cur@#_designation@#SR EXECUTIVE
# >> [31870, 1438] [800, 28]
# processing> cur@#_approved_credit_limit@#79000.0
# >> [32466, 1449] [204, 17]
# [204, 17] of date_field	[cur@#_approved_credit_limit@#79000.0] is informative: p = 0.0187168070403
# processing> cur@#_marital_status@#2.0
# >> [25135, 1067] [7535, 399]
# [7535, 399] of date_field	[cur@#_marital_status@#2.0] is informative: p = 0.000310815339454
# processing> cur@#_acq_source@#SA14
# >> [32537, 1450] [133, 16]
# [133, 16] of date_field	[cur@#_acq_source@#SA14] is informative: p = 0.000702061727341
# processing> cur@#_approved_credit_limit@#64000.0
# >> [32463, 1449] [207, 17]
# [207, 17] of date_field	[cur@#_approved_credit_limit@#64000.0] is informative: p = 0.0202734187246
# processing> cur@#_existing_card_issuer@#Citibank N.A.
# >> [30616, 1395] [2054, 71]
# [2054, 71] of date_field	[cur@#_existing_card_issuer@#Citibank N.A.] is informative: p = 0.0234602357003
# processing> cur@#_existing_bank@#AXIS Bank
# >> [31971, 1430] [699, 36]
# processing> cur@#_approved_credit_limit@#104000.0
# >> [32417, 1453] [253, 13]
# processing> cur@#_approved_credit_limit@#86000.0
# >> [32490, 1457] [180, 9]
# processing> cur@#_status_type@#14.0
# >> [23, 1] [32647, 1465]
# processing> cur@#_edu_qualification@#Others
# >> [32451, 1455] [219, 11]
# processing> cur@#_approved_credit_limit@#105000.0
# >> [32364, 1449] [306, 17]
# processing> cur@#_app_perm_city@#8.0
# >> [31998, 1451] [672, 15]
# [672, 15] of date_field	[cur@#_app_perm_city@#8.0] is informative: p = 0.0041208883965
# processing> cur@#_existing_card_issuer@#Kotak Mahindra Bank Ltd.
# >> [32470, 1459] [200, 7]
# processing> cur@#_approved_credit_limit@#92000.0
# >> [32426, 1459] [244, 7]
# processing> cur@#_approved_credit_limit@#109000.0
# >> [32466, 1453] [204, 13]
# processing> cur@#_promo_code@#INDX
# >> [29253, 1293] [3417, 173]
# processing> cur@#_acq_source@#SA35
# >> [32514, 1458] [156, 8]
# processing> cur@#_acq_source@#SA32
# >> [31884, 1425] [786, 41]
# processing> cur@#_acq_source@#SA31
# >> [32048, 1441] [622, 25]
# processing> cur@#_acq_source@#SA38
# >> [32428, 1445] [242, 21]
# [242, 21] of date_field	[cur@#_acq_source@#SA38] is informative: p = 0.00832231760164
# processing> cur@#_se_code@#IN01
# >> [32265, 1440] [405, 26]
# processing> cur@#_existing_bank@#Citibank N.A.
# >> [32413, 1452] [257, 14]
# processing> cur@#_approved_credit_limit@#58000.0
# >> [32446, 1444] [224, 22]
# [224, 22] of date_field	[cur@#_approved_credit_limit@#58000.0] is informative: p = 0.00124507747729
# processing> cur@#_approved_credit_limit@#129000.0
# >> [32472, 1462] [198, 4]
# processing> cur@#_designation@#ENGINEER
# >> [32393, 1451] [277, 15]
# processing> cur@#_mktg_code@#nan
# >> [30, 1] [32640, 1465]
# processing> cur@#_se_code@#A005
# >> [32536, 1464] [134, 2]
# processing> cur@#_approved_credit_limit@#66000.0
# >> [32450, 1458] [220, 8]
# processing> cur@#_office_city@#Ahmedabad
# >> [31984, 1453] [686, 13]
# [686, 13] of date_field	[cur@#_office_city@#Ahmedabad] is informative: p = 0.000624153168162
# processing> cur@#_approved_credit_limit@#117000.0
# >> [32374, 1458] [296, 8]
# processing> cur@#_se_code@#D135
# >> [32530, 1457] [140, 9]
# processing> cur@#_lead_code@#5622
# >> [32435, 1461] [235, 5]
# processing> cur@#_app_state@#13.0
# >> [29302, 1306] [3368, 160]
# processing> cur@#_approved_credit_limit@#150000.0
# >> [32107, 1450] [563, 16]
# processing> cur@#_designation@#ASSOCIATE
# >> [32507, 1456] [163, 10]
# processing> cur@#_existing_card_issuer@#HSBC Bank
# >> [32498, 1465] [172, 1]
# [172, 1] of date_field	[cur@#_existing_card_issuer@#HSBC Bank] is informative: p = 0.00767045247133
# processing> cur@#_approved_credit_limit@#96000.0
# >> [32391, 1454] [279, 12]
# processing> cur@#_app_res_city@#Vadodara
# >> [32111, 1448] [559, 18]
# processing> cur@#_approved_credit_limit@#67000.0
# >> [32472, 1451] [198, 15]
# processing> cur@#_se_code@#G010
# >> [32026, 1427] [644, 39]
# processing> cur@#_card_name@#RBL Bank Fun+
# >> [32364, 1456] [306, 10]
# processing> cur@#_app_office_state@#31.0
# >> [32071, 1452] [599, 14]
# [599, 14] of date_field	[cur@#_app_office_state@#31.0] is informative: p = 0.0114732431806
# processing> cur@#_worst_dpd6@#9
# >> [32224, 1466] [446, 0]
# [446, 0] of date_field	[cur@#_worst_dpd6@#9] is informative: p = 4.94136229104e-09
# processing> cur@#_worst_dpd6@#0
# >> [4819, 1466] [27851, 0]
# [27851, 0] of date_field	[cur@#_worst_dpd6@#0] is informative: p = 0.0
# processing> cur@#_approved_credit_limit@#119000.0
# >> [32415, 1461] [255, 5]
# processing> cur@#_approved_credit_limit@#80000.0
# >> [32394, 1460] [276, 6]
# processing> cur@#_fee_code@#TD2
# >> [32570, 1465] [100, 1]
# processing> cur@#_fee_code@#TD1
# >> [24533, 1145] [8137, 321]
# [8137, 321] of date_field	[cur@#_fee_code@#TD1] is informative: p = 0.0085806069437
# processing> cur@#_promo_code@#VNPX
# >> [28911, 1262] [3759, 204]
# [3759, 204] of date_field	[cur@#_promo_code@#VNPX] is informative: p = 0.00591040033653
# processing> cur@#_designation@#OFFICER
# >> [32362, 1458] [308, 8]
# processing> cur@#_app_perm_state@#26.0
# >> [32432, 1455] [238, 11]
# processing> cur@#_approved_credit_limit@#114000.0
# >> [32422, 1457] [248, 9]
# processing> cur@#_app_perm_city@#667.0
# >> [32395, 1452] [275, 14]
# processing> cur@#_approved_credit_limit@#69000.0
# >> [32457, 1460] [213, 6]
# processing> cur@#_acq_source@#HARI
# >> [32567, 1454] [103, 12]
# [103, 12] of date_field	[cur@#_acq_source@#HARI] is informative: p = 0.00394697244631
# processing> cur@#_approved_credit_limit@#147000.0
# >> [32538, 1465] [132, 1]
# [132, 1] of date_field	[cur@#_approved_credit_limit@#147000.0] is informative: p = 0.0486012493411
# processing> cur@#_worst_dpd6@#10
# >> [31463, 1466] [1207, 0]
# [1207, 0] of date_field	[cur@#_worst_dpd6@#10] is informative: p = 5.61879862303e-24
# processing> cur@#_worst_dpd6@#11
# >> [29504, 1466] [3166, 0]
# [3166, 0] of date_field	[cur@#_worst_dpd6@#11] is informative: p = 8.96311389444e-64
# processing> cur@#_app_international_transaction_fl@#Y
# >> [1739, 94] [30931, 1372]
# processing> cur@#_app_international_transaction_fl@#N
# >> [30954, 1373] [1716, 93]
# processing> cur@#_company_type@#nan
# >> [24945, 1061] [7725, 405]
# [7725, 405] of date_field	[cur@#_company_type@#nan] is informative: p = 0.000562408746371
# processing> cur@#_approved_credit_limit@#60000.0
# >> [32420, 1440] [250, 26]
# [250, 26] of date_field	[cur@#_approved_credit_limit@#60000.0] is informative: p = 0.000234401240555
# processing> cur@#_lead_code@#nan
# >> [1411, 44] [31259, 1422]
# [31259, 1422] of date_field	[cur@#_lead_code@#nan] is informative: p = 0.0142431788012
# processing> cur@#_app_perm_state@#17.0
# >> [31931, 1421] [739, 45]
# [739, 45] of date_field	[cur@#_app_perm_state@#17.0] is informative: p = 0.0493989926239
# processing> cur@#_app_disposition@#Card Setup
# >> [23, 1] [32647, 1465]
# processing> cur@#_approved_credit_limit@#138000.0
# >> [32493, 1462] [177, 4]
# processing> cur@#_app_perm_city@#186.0
# >> [32113, 1448] [557, 18]
# processing> cur@#_approved_credit_limit@#134000.0
# >> [32480, 1459] [190, 7]
# processing> cur@#_app_perm_country@#1.0
# >> [26688, 1179] [5982, 287]
# processing> cur@#_approved_credit_limit@#50000.0
# >> [32046, 1419] [624, 47]
# [624, 47] of date_field	[cur@#_approved_credit_limit@#50000.0] is informative: p = 0.00102480395309
# processing> cur@#_app_existing_other_loan_cc@#nan
# >> [3289, 142] [29381, 1324]
# processing> cur@#_app_title@#1.0
# >> [1660, 85] [31010, 1381]
# processing> cur@#_worst_dpd6@#71
# >> [32670, 1215] [0, 251]
# [0, 251] of date_field	[cur@#_worst_dpd6@#71] is informative: p = 0.0
# processing> cur@#_designation@#DIRECTOR
# >> [32551, 1464] [119, 2]
# processing> cur@#_designation@#SR OFFICER
# >> [32525, 1464] [145, 2]
# processing> cur@#_approved_credit_limit@#168000.0
# >> [32561, 1465] [109, 1]
# processing> cur@#_se_code@#D094
# >> [32552, 1453] [118, 13]
# [118, 13] of date_field	[cur@#_se_code@#D094] is informative: p = 0.00426568781604
# processing> cur@#_approved_credit_limit@#78000.0
# >> [32441, 1462] [229, 4]
# processing> cur@#_approved_credit_limit@#82000.0
# >> [32452, 1449] [218, 17]
# [218, 17] of date_field	[cur@#_approved_credit_limit@#82000.0] is informative: p = 0.0342067931288
# processing> cur@#_designation@#MANAGER
# >> [30472, 1395] [2198, 71]
# [2198, 71] of date_field	[cur@#_designation@#MANAGER] is informative: p = 0.00375871233808
# processing> cur@#_app_perm_city@#56.0
# >> [32545, 1463] [125, 3]
# processing> cur@#_promo_code@#VNTX
# >> [30925, 1376] [1745, 90]
# processing> cur@#_app_res_city@#Kolhapur
# >> [32567, 1465] [103, 1]
# processing> cur@#_app_existing_rbl_cust@#N
# >> [654, 11] [32016, 1455]
# [32016, 1455] of date_field	[cur@#_app_existing_rbl_cust@#N] is informative: p = 0.000215392535071
# processing> cur@#_approved_credit_limit@#156000.0
# >> [32513, 1463] [157, 3]
# processing> cur@#_app_pref_mailing_addr@#R
# >> [11437, 471] [21233, 995]
# [21233, 995] of date_field	[cur@#_app_pref_mailing_addr@#R] is informative: p = 0.025014519078
# processing> cur@#_app_pref_mailing_addr@#O
# >> [21256, 996] [11414, 470]
# [11414, 470] of date_field	[cur@#_app_pref_mailing_addr@#O] is informative: p = 0.024946708161
# processing> cur@#_app_res_city@#Coimbatore
# >> [32559, 1466] [111, 0]
# [111, 0] of date_field	[cur@#_app_res_city@#Coimbatore] is informative: p = 0.0158693939194
# processing> cur@#_aip_status@#3.0
# >> [12684, 538] [19986, 928]
# processing> cur@#_app_perm_state@#29.0
# >> [32429, 1456] [241, 10]
# processing> cur@#_app_office_state@#17.0
# >> [31942, 1422] [728, 44]
# processing> cur@#_worst_dpd6@#101
# >> [32670, 1328] [0, 138]
# [0, 138] of date_field	[cur@#_worst_dpd6@#101] is informative: p = 3.72621718797e-192
# processing> cur@#_existing_card_issuer@#Standard Chartered Bank
# >> [32023, 1450] [647, 16]
# [647, 16] of date_field	[cur@#_existing_card_issuer@#Standard Chartered Bank] is informative: p = 0.0150288463642
# processing> cur@#_acq_source@#DP02
# >> [32549, 1463] [121, 3]
# processing> cur@#_approved_credit_limit@#62000.0
# >> [32433, 1454] [237, 12]
# processing> cur@#_designation@#ACCOUNT MANAGER
# >> [32563, 1464] [107, 2]
# processing> cur@#_designation@#TEACHER
# >> [32572, 1460] [98, 6]
# processing> cur@#_company_type@#Proprietorship
# >> [30358, 1361] [2312, 105]
# processing> cur@#_industry_type@#Health Care
# >> [32402, 1456] [268, 10]
# processing> cur@#_app_si_ecs_flg@#N
# >> [465, 3] [32205, 1463]
# [32205, 1463] of date_field	[cur@#_app_si_ecs_flg@#N] is informative: p = 4.71741126007e-06
# processing> cur@#_fee_code@#PM1
# >> [20709, 795] [11961, 671]
# [11961, 671] of date_field	[cur@#_fee_code@#PM1] is informative: p = 2.34205171091e-12
# processing> cur@#_fee_code@#PM2
# >> [32403, 1466] [267, 0]
# [267, 0] of date_field	[cur@#_fee_code@#PM2] is informative: p = 1.27055211156e-05
# processing> cur@#_se_code@#D054
# >> [32547, 1459] [123, 7]
# processing> cur@#_approved_credit_limit@#122000.0
# >> [32405, 1463] [265, 3]
# [265, 3] of date_field	[cur@#_approved_credit_limit@#122000.0] is informative: p = 0.0057762804281
# processing> cur@#_app_resident_india@#Y
# >> [31, 1] [32639, 1465]
# processing> cur@#_app_state@#12.0
# >> [31340, 1433] [1330, 33]
# [1330, 33] of date_field	[cur@#_app_state@#12.0] is informative: p = 0.00022184713261
# processing> cur@#_aip_status@#1.0
# >> [23229, 1114] [9441, 352]
# [9441, 352] of date_field	[cur@#_aip_status@#1.0] is informative: p = 4.56560064185e-05
# processing> cur@#_override_fee_code@#TD3
# >> [29227, 1350] [3443, 116]
# [3443, 116] of date_field	[cur@#_override_fee_code@#TD3] is informative: p = 0.0010354746703
# processing> cur@#_approved_credit_limit@#106000.0
# >> [32407, 1458] [263, 8]
# processing> cur@#_industry_type@#Others
# >> [27925, 1249] [4745, 217]
# processing> cur@#_designation@#SALES EXECUTIVE
# >> [32521, 1457] [149, 9]
# processing> cur@#_promo_code@#INPX
# >> [29045, 1196] [3625, 270]
# [3625, 270] of date_field	[cur@#_promo_code@#INPX] is informative: p = 8.95880647418e-16
# processing> cur@#_app_title@#3.0
# >> [31526, 1414] [1144, 52]
# processing> cur@#_approved_credit_limit@#151000.0
# >> [32570, 1462] [100, 4]
# processing> cur@#_approved_credit_limit@#108000.0
# >> [32399, 1453] [271, 13]
# processing> cur@#_existing_card_issuer@#HDFC Bank
# >> [24769, 1202] [7901, 264]
# [7901, 264] of date_field	[cur@#_existing_card_issuer@#HDFC Bank] is informative: p = 2.85341117111e-08
# processing> cur@#_se_code@#MA01
# >> [30917, 1373] [1753, 93]
# processing> cur@#_existing_card_issuer@#American Express Banking Corporation
# >> [32561, 1462] [109, 4]
# processing> cur@#_se_code@#D073
# >> [32392, 1449] [278, 17]
# processing> cur@#_override_months@#nan
# >> [22280, 860] [10390, 606]
# [10390, 606] of date_field	[cur@#_override_months@#nan] is informative: p = 7.43788571102e-14
# processing> cur@#_designation@#PROJECT MANAGER
# >> [32573, 1463] [97, 3]
# processing> cur@#_designation@#ASST MGR
# >> [32555, 1463] [115, 3]
# processing> cur@#_office_city@#Pune
# >> [32283, 1449] [387, 17]
# processing> cur@#_app_perm_city@#39.0
# >> [31327, 1395] [1343, 71]
# processing> cur@#_se_code@#H004
# >> [32558, 1456] [112, 10]
# [112, 10] of date_field	[cur@#_se_code@#H004] is informative: p = 0.0422196527744
# processing> cur@#_se_code@#H006
# >> [32475, 1457] [195, 9]
# processing> cur@#_months_exp@#0.0
# >> [988, 46] [31682, 1420]
# processing> cur@#_app_perm_city@#157.0
# >> [18560, 787] [14110, 679]
# [14110, 679] of date_field	[cur@#_app_perm_city@#157.0] is informative: p = 0.0190731813965
# processing> cur@#_approved_credit_limit@#139000.0
# >> [32551, 1463] [119, 3]
# processing> cur@#_acq_source@#MA24
# >> [32540, 1464] [130, 2]
# processing> cur@#_acq_source@#MA25
# >> [32455, 1458] [215, 8]
# processing> cur@#_acq_source@#MA20
# >> [32562, 1461] [108, 5]
# processing> cur@#_approved_credit_limit@#55000.0
# >> [32492, 1448] [178, 18]
# [178, 18] of date_field	[cur@#_approved_credit_limit@#55000.0] is informative: p = 0.00225125580921
# processing> cur@#_app_perm_city@#315.0
# >> [32032, 1435] [638, 31]
# processing> cur@#_se_code@#M032
# >> [32543, 1457] [127, 9]
# processing> cur@#_id_proof@#nan
# >> [32529, 1463] [141, 3]
# processing> cur@#_months_exp@#5.0
# >> [32208, 1447] [462, 19]
# processing> cur@#_acq_source@#MA01
# >> [32527, 1461] [143, 5]
# processing> cur@#_acq_source@#MA02
# >> [32488, 1460] [182, 6]
# processing> cur@#_acq_source@#MA03
# >> [31909, 1450] [761, 16]
# [761, 16] of date_field	[cur@#_acq_source@#MA03] is informative: p = 0.000881472179844
# processing> cur@#_edu_qualification@#Professional
# >> [32500, 1462] [170, 4]
# processing> cur@#_approved_credit_limit@#195000.0
# >> [32545, 1456] [125, 10]
# processing> cur@#_promo_code@#INTX
# >> [31548, 1396] [1122, 70]
# [1122, 70] of date_field	[cur@#_promo_code@#INTX] is informative: p = 0.0086617901332
# processing> cur@#_aip_status@#2.0
# >> [29450, 1281] [3220, 185]
# [3220, 185] of date_field	[cur@#_aip_status@#2.0] is informative: p = 0.000819953700762
# processing> cur@#_approved_credit_limit@#116000.0
# >> [32459, 1458] [211, 8]
# processing> cur@#_approved_credit_limit@#83000.0
# >> [32463, 1456] [207, 10]
# processing> cur@#_industry_type@#Banking/Financial Services
# >> [14641, 717] [18029, 749]
# [18029, 749] of date_field	[cur@#_industry_type@#Banking/Financial Services] is informative: p = 0.00221260057434
# processing> cur@#_se_code@#TMS1
# >> [32452, 1458] [218, 8]
# processing> cur@#_card_name@#Platinum Deligh
# >> [20951, 1019] [11719, 447]
# [11719, 447] of date_field	[cur@#_card_name@#Platinum Deligh] is informative: p = 2.23823505917e-05
# processing> cur@#_approved_credit_limit@#97000.0
# >> [32375, 1451] [295, 15]
# processing> cur@#_se_code@#RK01
# >> [32216, 1445] [454, 21]
# processing> cur@#_se_code@#RK02
# >> [32342, 1447] [328, 19]
# processing> cur@#_approved_credit_limit@#137000.0
# >> [32458, 1463] [212, 3]
# [212, 3] of date_field	[cur@#_approved_credit_limit@#137000.0] is informative: p = 0.0278497503582
# processing> cur@#_se_code@#FS02
# >> [32553, 1465] [117, 1]
# processing> cur@#_app_res_city@#Mumbai / Navi Mumbai / Thane
# >> [30334, 1371] [2336, 95]
# processing> cur@#_designation@#ACCOUNTANT
# >> [32228, 1452] [442, 14]
# processing> cur@#_approved_credit_limit@#136000.0
# >> [32487, 1463] [183, 3]
# processing> cur@#_approved_credit_limit@#107000.0
# >> [32426, 1459] [244, 7]
# processing> cur@#_designation@#nan
# >> [24945, 1061] [7725, 405]
# [7725, 405] of date_field	[cur@#_designation@#nan] is informative: p = 0.000562408746371
# processing> cur@#_app_memo_status@#1.0
# >> [1329, 55] [31341, 1411]
# processing> cur@#_se_code@#G014
# >> [32520, 1461] [150, 5]
# processing> cur@#_se_code@#G013
# >> [32504, 1459] [166, 7]
# processing> cur@#_se_code@#G011
# >> [32064, 1433] [606, 33]
# processing> cur@#_rbl_relationship_no@#nan
# >> [156, 3] [32514, 1463]
# processing> cur@#_se_code@#S203
# >> [32558, 1463] [112, 3]
# processing> cur@#_se_code@#S202
# >> [32545, 1463] [125, 3]
# processing> cur@#_promo_code@#TTTX
# >> [31973, 1420] [697, 46]
# [697, 46] of date_field	[cur@#_promo_code@#TTTX] is informative: p = 0.013244313994
# processing> cur@#_approved_credit_limit@#72000.0
# >> [32454, 1451] [216, 15]
# processing> cur@#_approved_credit_limit@#98000.0
# >> [32391, 1459] [279, 7]
# processing> cur@#_designation@#SUPERVISOR
# >> [32517, 1453] [153, 13]
# [153, 13] of date_field	[cur@#_designation@#SUPERVISOR] is informative: p = 0.0329251912427
# processing> cur@#_existing_bank@#nan
# >> [7420, 351] [25250, 1115]
# processing> cur@#_edu_qualification@#nan
# >> [27693, 1273] [4977, 193]
# [4977, 193] of date_field	[cur@#_edu_qualification@#nan] is informative: p = 0.0307450506026
# processing> cur@#_edu_qualification@#MBA/MMS
# >> [32363, 1453] [307, 13]
# processing> cur@#_approved_credit_limit@#99000.0
# >> [32386, 1457] [284, 9]
# processing> cur@#_existing_card_issuer@#ICICI Bank
# >> [31831, 1443] [839, 23]
# [839, 23] of date_field	[cur@#_existing_card_issuer@#ICICI Bank] is informative: p = 0.01674177752
# processing> cur@#_approved_credit_limit@#154000.0
# >> [32566, 1464] [104, 2]
# processing> cur@#_rbl_relationship_no@#309000000000.0
# >> [32562, 1464] [108, 2]
# processing> cur@#_se_code@#AS03
# >> [30933, 1406] [1737, 60]
# [1737, 60] of date_field	[cur@#_se_code@#AS03] is informative: p = 0.0418284233175
# processing> cur@#_se_code@#AS04
# >> [32442, 1457] [228, 9]
# processing> cur@#_se_code@#AS06
# >> [31734, 1425] [936, 41]
# processing> cur@#_approved_credit_limit@#133000.0
# >> [32505, 1457] [165, 9]
# processing> cur@#_company_type@#Public Ltd Co.
# >> [24963, 1148] [7707, 318]
# processing> cur@#_app_employment_type@#1.0
# >> [7725, 405] [24945, 1061]
# [24945, 1061] of date_field	[cur@#_app_employment_type@#1.0] is informative: p = 0.000562408746371
# processing> cur@#_app_perm_city@#71.0
# >> [32097, 1430] [573, 36]
# processing> cur@#_approved_credit_limit@#95000.0
# >> [32381, 1456] [289, 10]
# processing> cur@#_app_existing_other_loan_cc@#Y
# >> [29578, 1332] [3092, 134]
# processing> cur@#_app_existing_other_loan_cc@#N
# >> [32473, 1458] [197, 8]
# processing> cur@#_app_title@#2.0
# >> [32186, 1436] [484, 30]
# processing> cur@#_edu_qualification@#Doctor
# >> [32432, 1454] [238, 12]
# processing> cur@#_app_employment_type@#2.0
# >> [25014, 1063] [7656, 403]
# [7656, 403] of date_field	[cur@#_app_employment_type@#2.0] is informative: p = 0.000427309314952
# processing> cur@#_approved_credit_limit@#135000.0
# >> [32466, 1459] [204, 7]
# processing> cur@#_approved_credit_limit@#59000.0
# >> [32402, 1445] [268, 21]
# [268, 21] of date_field	[cur@#_approved_credit_limit@#59000.0] is informative: p = 0.0186308159208
# processing> cur@#_app_office_state@#33.0
# >> [28148, 1254] [4522, 212]
# processing> cur@#_promo_code@#TTPX
# >> [32053, 1413] [617, 53]
# [617, 53] of date_field	[cur@#_promo_code@#TTPX] is informative: p = 2.76498802266e-05
# processing> cur@#_approved_credit_limit@#144000.0
# >> [32526, 1462] [144, 4]
# processing> cur@#_app_res_city@#Faridabad
# >> [31214, 1387] [1456, 79]
# processing> cur@#_approved_credit_limit@#128000.0
# >> [32453, 1458] [217, 8]
# processing> cur@#_acq_source@#88
# >> [32569, 1464] [101, 2]
# processing> cur@#_app_memo_status@#2.0
# >> [31508, 1425] [1162, 41]
# processing> cur@#_app_perm_state@#35.0
# >> [32476, 1455] [194, 11]
# processing> cur@#_office_city@#Chennai
# >> [32334, 1460] [336, 6]
# [336, 6] of date_field	[cur@#_office_city@#Chennai] is informative: p = 0.0151971892694
# processing> cur@#_acq_source@#W01
# >> [31718, 1419] [952, 47]
# processing> cur@#_app_state@#31.0
# >> [32068, 1452] [602, 14]
# [602, 14] of date_field	[cur@#_app_state@#31.0] is informative: p = 0.00898111561707
# processing> cur@#_app_res_city@#Pune
# >> [32283, 1449] [387, 17]
# processing> cur@#_override_fee_code@#PD3
# >> [21123, 1024] [11547, 442]
# [11547, 442] of date_field	[cur@#_override_fee_code@#PD3] is informative: p = 3.90660173715e-05
# processing> cur@#_approved_credit_limit@#30000.0
# >> [32147, 1411] [523, 55]
# [523, 55] of date_field	[cur@#_approved_credit_limit@#30000.0] is informative: p = 4.08190372002e-08
# processing> cur@#_intl_trn@#N
# >> [30954, 1373] [1716, 93]
# processing> cur@#_intl_trn@#Y
# >> [1739, 94] [30931, 1372]
# processing> cur@#_months_exp@#6.0
# >> [32396, 1450] [274, 16]
# processing> cur@#_approved_credit_limit@#180000.0
# >> [32555, 1459] [115, 7]
# processing> cur@#_app_state@#10.0
# >> [15453, 639] [17217, 827]
# [17217, 827] of date_field	[cur@#_app_state@#10.0] is informative: p = 0.0054111982981
# processing> cur@#_edu_qualification@#Post-Graduate
# >> [26366, 1210] [6304, 256]
# processing> cur@#_approved_credit_limit@#153000.0
# >> [32564, 1465] [106, 1]
# processing> cur@#_acq_source@#SA05
# >> [30741, 1363] [1929, 103]
# processing> cur@#_acq_source@#SA03
# >> [19794, 927] [12876, 539]
# [12876, 539] of date_field	[cur@#_acq_source@#SA03] is informative: p = 0.0431296051245
# processing> cur@#_acq_source@#SA01
# >> [30821, 1365] [1849, 101]
# processing> cur@#_designation@#SR MANAGER
# >> [32346, 1454] [324, 12]
# processing> cur@#_employment_type@#1.0
# >> [7725, 405] [24945, 1061]
# [24945, 1061] of date_field	[cur@#_employment_type@#1.0] is informative: p = 0.000562408746371
# processing> cur@#_office_city@#Hyderabad
# >> [29725, 1350] [2945, 116]
# processing> cur@#_approved_credit_limit@#93000.0
# >> [32420, 1458] [250, 8]
# processing> cur@#_app_perm_state@#21.0
# >> [29842, 1351] [2828, 115]
# processing> cur@#_designation@#EXECUTIVE
# >> [31762, 1417] [908, 49]
# processing> cur@#_acq_source@#BBD1
# >> [32507, 1451] [163, 15]
# [163, 15] of date_field	[cur@#_acq_source@#BBD1] is informative: p = 0.0136765988999
# processing> cur@#_office_city@#Navi mumbai
# >> [32550, 1459] [120, 7]
# processing> cur@#_promo_code@#CNDX
# >> [31127, 1435] [1543, 31]
# [1543, 31] of date_field	[cur@#_promo_code@#CNDX] is informative: p = 4.10035928735e-07
# processing> cur@#_designation@#SR ACCOUNTANT
# >> [32553, 1461] [117, 5]
# processing> cur@#_employment_type@#2.0
# >> [25014, 1063] [7656, 403]
# [7656, 403] of date_field	[cur@#_employment_type@#2.0] is informative: p = 0.000427309314952
# processing> cur@#_approved_credit_limit@#115000.0
# >> [32456, 1455] [214, 11]
# processing> cur@#_se_code@#SRC1
# >> [32511, 1458] [159, 8]
# processing> cur@#_edu_qualification@#Graduate
# >> [12658, 502] [20012, 964]
# [20012, 964] of date_field	[cur@#_edu_qualification@#Graduate] is informative: p = 0.00054470942637
# processing> cur@#_app_perm_state@#10.0
# >> [18559, 787] [14111, 679]
# [14111, 679] of date_field	[cur@#_app_perm_state@#10.0] is informative: p = 0.0190771068515
# processing> cur@#_app_office_state@#12.0
# >> [31342, 1433] [1328, 33]
# [1328, 33] of date_field	[cur@#_app_office_state@#12.0] is informative: p = 0.000279717633378
# processing> cur@#_se_code@#MA03
# >> [32497, 1458] [173, 8]
# processing> cur@#_se_code@#S001
# >> [32525, 1456] [145, 10]
# processing> cur@#_approved_credit_limit@#89000.0
# >> [32437, 1454] [233, 12]
# processing> cur@#_office_city@#Faridabad
# >> [31729, 1414] [941, 52]
# processing> cur@#_se_code@#D077
# >> [32219, 1443] [451, 23]
# processing> cur@#_approved_credit_limit@#127000.0
# >> [32456, 1459] [214, 7]
# processing> cur@#_approved_credit_limit@#65000.0
# >> [32432, 1451] [238, 15]
# processing> cur@#_acq_source@#DM02
# >> [32500, 1458] [170, 8]
# processing> cur@#_acq_source@#BA05
# >> [32133, 1432] [537, 34]
# processing> cur@#_app_gender@#1.0
# >> [1651, 83] [31019, 1383]
# processing> cur@#_app_perm_country@#0.0
# >> [6005, 288] [26665, 1178]
# processing> cur@#_permanent_same@#Y
# >> [6005, 288] [26665, 1178]
# processing> cur@#_approved_credit_limit@#118000.0
# >> [32425, 1457] [245, 9]
# processing> cur@#_permanent_same@#N
# >> [26688, 1179] [5982, 287]
# processing> cur@#_approved_credit_limit@#48000.0
# >> [32577, 1458] [93, 8]
# processing> cur@#_se_code@#D120
# >> [32506, 1451] [164, 15]
# [164, 15] of date_field	[cur@#_se_code@#D120] is informative: p = 0.0140392869114
# processing> cur@#_acq_source@#SA43
# >> [32085, 1447] [585, 19]
# processing> cur@#_acq_source@#SA40
# >> [31665, 1422] [1005, 44]
# processing> cur@#_approved_credit_limit@#87000.0
# >> [32462, 1456] [208, 10]
# processing> cur@#_approved_credit_limit@#91000.0
# >> [32393, 1448] [277, 18]
# processing> cur@#_acq_source@#CD01
# >> [32291, 1439] [379, 27]
# [379, 27] of date_field	[cur@#_acq_source@#CD01] is informative: p = 0.02561953563
# processing> cur@#_approved_credit_limit@#149000.0
# >> [32546, 1461] [124, 5]
# processing> cur@#_app_state@#17.0
# >> [31940, 1421] [730, 45]
# [730, 45] of date_field	[cur@#_app_state@#17.0] is informative: p = 0.0391953581652
# processing> cur@#_designation@#SOFTWARE ENGINEER
# >> [32554, 1462] [116, 4]
# processing> cur@#_app_res_city@#Chennai
# >> [32401, 1456] [269, 10]
# processing> cur@#_app_has_card@#N
# >> [17401, 556] [15269, 910]
# [15269, 910] of date_field	[cur@#_app_has_card@#N] is informative: p = 1.04883182013e-30
# processing> cur@#_app_has_card@#Y
# >> [15292, 911] [17378, 555]
# [17378, 555] of date_field	[cur@#_app_has_card@#Y] is informative: p = 1.05967974985e-30
# processing> cur@#_office_city@#Vadodara
# >> [32114, 1447] [556, 19]
# processing> cur@#_company_type@#MNC
# >> [30614, 1372] [2056, 94]
# processing> cur@#_approved_credit_limit@#35000.0
# >> [31602, 1404] [1068, 62]
# processing> cur@#_id_proof@#Driving License
# >> [32274, 1449] [396, 17]
# processing> cur@#_app_perm_state@#34.0
# >> [32447, 1454] [223, 12]
# processing> cur@#_app_res_city@#Gurgaon
# >> [30774, 1385] [1896, 81]
# processing> cur@#_acq_source@#DD01
# >> [32342, 1455] [328, 11]
# processing> cur@#_approved_credit_limit@#54000.0
# >> [32511, 1451] [159, 15]
# [159, 15] of date_field	[cur@#_approved_credit_limit@#54000.0] is informative: p = 0.0124645016446
# processing> cur@#_app_perm_state@#2.0
# >> [29344, 1342] [3326, 124]
# [3326, 124] of date_field	[cur@#_app_perm_state@#2.0] is informative: p = 0.0333897743363
# processing> cur@#_approved_credit_limit@#159000.0
# >> [32568, 1460] [102, 6]
# processing> cur@#_id_proof@#Aadhar Card
# >> [32381, 1452] [289, 14]
# processing> cur@#_app_perm_city@#34.0
# >> [32569, 1466] [101, 0]
# [101, 0] of date_field	[cur@#_app_perm_city@#34.0] is informative: p = 0.0233712798595
# processing> cur@#_app_memo_status@#3.0
# >> [32526, 1453] [144, 13]
# [144, 13] of date_field	[cur@#_app_memo_status@#3.0] is informative: p = 0.0262196333575
# processing> cur@#_app_perm_city@#7.0
# >> [32558, 1461] [112, 5]
# processing> cur@#_approved_credit_limit@#51000.0
# >> [32555, 1456] [115, 10]
# processing> cur@#_approved_credit_limit@#113000.0
# >> [32420, 1453] [250, 13]
# processing> cur@#_override_months@#12.0
# >> [17618, 904] [15052, 562]
# [15052, 562] of date_field	[cur@#_override_months@#12.0] is informative: p = 5.72885298895e-09
# processing> cur@#_acq_source@#AC01
# >> [32361, 1452] [309, 14]
# processing> cur@#_approved_credit_limit@#112000.0
# >> [32434, 1453] [236, 13]
# processing> cur@#_office_city@#New Delhi
# >> [19234, 854] [13436, 612]
# processing> cur@#_app_res_city@#Tiruvallur
# >> [32563, 1464] [107, 2]
# processing> cur@#_office_city@#Ghaziabad
# >> [31966, 1424] [704, 42]
# processing> cur@#_company_type@#Private Ltd. Co.
# >> [20757, 965] [11913, 501]
# processing> cur@#_approved_credit_limit@#81000.0
# >> [32450, 1454] [220, 12]
# processing> cur@#_app_perm_state@#13.0
# >> [29875, 1334] [2795, 132]
# processing> cur@#_existing_bank@#ICICI Bank
# >> [31145, 1393] [1525, 73]
# processing> cur@#_approved_credit_limit@#73000.0
# >> [32463, 1454] [207, 12]
# processing> cur@#_designation@#ASST MANAGER
# >> [31599, 1413] [1071, 53]
# processing> cur@#_app_addon_card_dob@#0000-00-00
# >> [107, 5] [32563, 1461]
# processing> cur@#_app_gender@#2.0
# >> [31042, 1384] [1628, 82]
# processing> cur@#_designation@#DEPUTY MANAGER
# >> [32466, 1456] [204, 10]
# processing> cur@#_app_res_city@#Noida / Greater Noida
# >> [31511, 1395] [1159, 71]
# [1159, 71] of date_field	[cur@#_app_res_city@#Noida / Greater Noida] is informative: p = 0.0119868704052
# processing> cur@#_se_code@#V003
# >> [32543, 1461] [127, 5]
# processing> cur@#_se_code@#V001
# >> [32177, 1446] [493, 20]
# processing> cur@#_approved_credit_limit@#142000.0
# >> [32519, 1465] [151, 1]
# [151, 1] of date_field	[cur@#_approved_credit_limit@#142000.0] is informative: p = 0.0239958052956
# processing> cur@#_existing_card_issuer@#AXIS Bank
# >> [31258, 1421] [1412, 45]
# [1412, 45] of date_field	[cur@#_existing_card_issuer@#AXIS Bank] is informative: p = 0.0205242939379
# processing> cur@#_app_perm_city@#13.0
# >> [32405, 1457] [265, 9]
# processing> cur@#_promo_code@#TTDX
# >> [32576, 1460] [94, 6]
# processing> cur@#_office_city@#Rangareddy
# >> [32408, 1460] [262, 6]
# processing> cur@#_app_res_city@#Hyderabad / Secunderabad
# >> [29740, 1356] [2930, 110]
# processing> cur@#_app_perm_state@#20.0
# >> [32511, 1459] [159, 7]
# processing> cur@#_acq_source@#IB06
# >> [32542, 1463] [128, 3]
# processing> cur@#_acq_source@#IB04
# >> [32564, 1461] [106, 5]
# processing> cur@#_approved_credit_limit@#53000.0
# >> [32528, 1461] [142, 5]
# processing> cur@#_designation@#SALES OFFICER
# >> [32573, 1457] [97, 9]
# [97, 9] of date_field	[cur@#_designation@#SALES OFFICER] is informative: p = 0.0483381017181
# processing> cur@#_acq_source@#CH08
# >> [32543, 1463] [127, 3]
# processing> cur@#_promo_code@#ENPX
# >> [32564, 1466] [106, 0]
# [106, 0] of date_field	[cur@#_promo_code@#ENPX] is informative: p = 0.0153572653888
# processing> cur@#_designation@#ASSISTANT MANAGER
# >> [32508, 1459] [162, 7]
# processing> cur@#_app_perm_city@#3.0
# >> [31588, 1424] [1082, 42]
# processing> cur@#_approved_credit_limit@#120000.0
# >> [32297, 1450] [373, 16]
# processing> cur@#_id_proof@#PAN Card
# >> [1514, 59] [31156, 1407]
# processing> cur@#_app_addon_card_relationship@#0.0
# >> [110, 5] [32560, 1461]
# processing> cur@#_office_city@#Kolhapur
# >> [32557, 1464] [113, 2]
# processing> cur@#_app_perm_state@#5.0
# >> [31695, 1418] [975, 48]
# processing> cur@#_app_office_state@#13.0
# >> [26881, 1161] [5789, 305]
# [5789, 305] of date_field	[cur@#_app_office_state@#13.0] is informative: p = 0.00302997059987
# processing> cur@#_app_office_state@#21.0
# >> [29796, 1349] [2874, 117]
# processing> cur@#_approved_credit_limit@#123000.0
# >> [32459, 1456] [211, 10]
# processing> cur@#_approved_credit_limit@#143000.0
# >> [32510, 1462] [160, 4]
# processing> cur@#_approved_credit_limit@#52000.0
# >> [32554, 1458] [116, 8]
# processing> cur@#_approved_credit_limit@#148000.0
# >> [32562, 1463] [108, 3]
# processing> cur@#_se_code@#VA03
# >> [32158, 1450] [512, 16]
# processing> cur@#_se_code@#VA01
# >> [32210, 1450] [460, 16]
# processing> cur@#_app_perm_state@#33.0
# >> [28345, 1274] [4325, 192]
# processing> cur@#_designation@#SALES MANAGER
# >> [32378, 1450] [292, 16]
# processing> cur@#_designation@#STORE MANAGER
# >> [32456, 1458] [214, 8]
# processing> cur@#_designation@#TEAM LEADER
# >> [32334, 1454] [336, 12]
# processing> cur@#_company_type@#Government Organisation
# >> [31776, 1425] [894, 41]
# processing> cur@#_worst_dpd6@#41
# >> [32670, 1018] [0, 448]
# [0, 448] of date_field	[cur@#_worst_dpd6@#41] is informative: p = 0.0
# processing> cur@#_worst_dpd6@#40
# >> [32670, 1284] [0, 182]
# [0, 182] of date_field	[cur@#_worst_dpd6@#40] is informative: p = 2.02918169134e-254
# processing> cur@#_app_state@#33.0
# >> [29508, 1324] [3162, 142]
# processing> cur@#_promo_code@#CNPX
# >> [22203, 1102] [10467, 364]
# [10467, 364] of date_field	[cur@#_promo_code@#CNPX] is informative: p = 3.82998234637e-09
# processing> cur@#_app_si_ecs_flg@#Y
# >> [32228, 1464] [442, 2]
# [442, 2] of date_field	[cur@#_app_si_ecs_flg@#Y] is informative: p = 1.38357567069e-06
# processing> cur@#_acq_source@#HA07
# >> [32467, 1459] [203, 7]
# processing> cur@#_acq_source@#HA06
# >> [32201, 1450] [469, 16]
# processing> cur@#_acq_source@#HA03
# >> [31418, 1424] [1252, 42]
# processing> cur@#_approved_credit_limit@#158000.0
# >> [32565, 1465] [105, 1]
# processing> cur@#_acq_source@#HA09
# >> [32532, 1463] [138, 3]
# processing> cur@#_acq_source@#HA08
# >> [32095, 1441] [575, 25]
# processing> cur@#_existing_card_issuer@#IndusInd Bank Ltd.
# >> [32486, 1456] [184, 10]
# processing> cur@#_existing_bank@#Standard Chartered Bank
# >> [32494, 1453] [176, 13]
# processing> cur@#_lead_code@#5736
# >> [32546, 1461] [124, 5]
# processing> cur@#_designation@#SR ENGINEER
# >> [32486, 1460] [184, 6]
# processing> cur@#_approved_credit_limit@#101000.0
# >> [32427, 1456] [243, 10]
# processing> cur@#_approved_credit_limit@#90000.0
# >> [32275, 1451] [395, 15]
# processing> cur@#_approved_credit_limit@#100000.0
# >> [32186, 1441] [484, 25]
# processing> cur@#_app_res_city@#Ahmedabad
# >> [31994, 1451] [676, 15]
# [676, 15] of date_field	[cur@#_app_res_city@#Ahmedabad] is informative: p = 0.00321229698669
# processing> cur@#_app_perm_city@#14.0
# >> [29863, 1362] [2807, 104]
# [2807, 104] of date_field	[cur@#_app_perm_city@#14.0] is informative: p = 0.0446297535608
# processing> cur@#_office_city@#Noida
# >> [28977, 1300] [3693, 166]
# processing> cur@#_existing_bank@#Yes Bank
# >> [32514, 1458] [156, 8]
# processing> cur@#_approved_credit_limit@#141000.0
# >> [32524, 1460] [146, 6]
# processing> cur@#_office_city@#Mumbai
# >> [30889, 1397] [1781, 69]
# processing> cur@#_approved_credit_limit@#124000.0
# >> [32453, 1461] [217, 5]
# processing> cur@#_app_res_city@#Kanchipuram
# >> [32562, 1464] [108, 2]
# processing> cur@#_approved_credit_limit@#125000.0
# >> [32372, 1454] [298, 12]
# processing> cur@#_se_code@#H013
# >> [32542, 1463] [128, 3]
# processing> cur@#_approved_credit_limit@#63000.0
# >> [32361, 1451] [309, 15]
# processing> cur@#_se_code@#M001
# >> [32546, 1463] [124, 3]
# processing> cur@#_office_city@#Bangalore
# >> [31948, 1422] [722, 44]
# processing> cur@#_office_city@#Coimbatore
# >> [32563, 1466] [107, 0]
# [107, 0] of date_field	[cur@#_office_city@#Coimbatore] is informative: p = 0.0153765331102
# processing> cur@#_se_code@#RM03
# >> [32547, 1459] [123, 7]
# processing> cur@#_card_name@#Titanium Deligh
# >> [24433, 1145] [8237, 321]
# [8237, 321] of date_field	[cur@#_card_name@#Titanium Deligh] is informative: p = 0.00415940520767
# processing> cur@#_app_perm_city@#41.0
# >> [31054, 1401] [1616, 65]
# processing> cur@#_app_perm_state@#12.0
# >> [31335, 1432] [1335, 34]
# [1335, 34] of date_field	[cur@#_app_perm_state@#12.0] is informative: p = 0.000384735854822
# processing> cur@#_office_city@#Thane
# >> [32266, 1446] [404, 20]
# processing> cur@#_approved_credit_limit@#163000.0
# >> [32571, 1464] [99, 2]
# processing> cur@#_approved_credit_limit@#76000.0
# >> [32438, 1456] [232, 10]
# processing> cur@#_app_office_state@#10.0
# >> [19234, 854] [13436, 612]
# processing> cur@#_id_proof@#Passport
# >> [32164, 1446] [506, 20]
# processing> cur@#_promo_code@#CNTX
# >> [28029, 1349] [4641, 117]
# [4641, 117] of date_field	[cur@#_promo_code@#CNTX] is informative: p = 7.7167357974e-13
# processing> cur@#_se_code@#RSN1
# >> [32548, 1463] [122, 3]
# processing> cur@#_se_code@#D066
# >> [32430, 1458] [240, 8]
# processing> cur@#_se_code@#D067
# >> [32526, 1461] [144, 5]
# processing> cur@#_approved_credit_limit@#500000.0
# >> [32534, 1461] [136, 5]
# processing> cur@#_approved_credit_limit@#77000.0
# >> [32450, 1452] [220, 14]
# processing> cur@#_app_perm_city@#12.0
# >> [31938, 1422] [732, 44]
# processing> cur@#_approved_credit_limit@#88000.0
# >> [32413, 1458] [257, 8]
# processing> cur@#_designation@#ANALYST
# >> [32562, 1461] [108, 5]
# processing> cur@#_app_res_city@#New Delhi
# >> [15453, 639] [17217, 827]
# [17217, 827] of date_field	[cur@#_app_res_city@#New Delhi] is informative: p = 0.0054111982981
# processing> cur@#_res_type@#Compa
# >> [32464, 1457] [206, 9]
# processing> cur@#_mob_verified@#N
# >> [3152, 181] [29518, 1285]
# [29518, 1285] of date_field	[cur@#_mob_verified@#N] is informative: p = 0.00100752014823
# processing> cur@#_se_code@#RM04
# >> [32263, 1459] [407, 7]
# [407, 7] of date_field	[cur@#_se_code@#RM04] is informative: p = 0.0048385176626
# processing> cur@#_existing_card_issuer@#nan
# >> [17247, 551] [15423, 915]
# [15423, 915] of date_field	[cur@#_existing_card_issuer@#nan] is informative: p = 2.93208016088e-30
# processing> cur@#_app_go_green@#nan
# >> [4033, 186] [28637, 1280]
# processing> cur@#_app_office_state@#2.0
# >> [29378, 1342] [3292, 124]
# [3292, 124] of date_field	[cur@#_app_office_state@#2.0] is informative: p = 0.0451748854929
# processing> cur@#_approved_credit_limit@#57000.0
# >> [32459, 1451] [211, 15]
# Total kept features: 132

# %%
def get_the_cont_data_fields(df, cols, key_col, suf):
    num_rcds = len(df[key_col])
    colDict = defaultdict(list)
    print "num_uid to be processed: ", num_rcds
    for i in range(num_rcds):
        if i % 100000 == 0:
            print i
        uid = df[key_col][i]
        colDict["userid"].append(uid)
        for col in cols:
            colDict[suf + "@#_" + col].append(df[col][i])
    return colDict

# %%
suf = "cur"
cu_contColDict = get_the_cont_data_fields(df_rawData, cu_cont_cols, key_col, suf)
# Out:
# num_uid to be processed:  34136
# 0

# %%
def train_test_dict(df_rawData70, key_col):
    uid_trainYes = defaultdict(int)
    num_rcds = len(df_rawData70[key_col])
    for i in range(num_rcds):
        uid = str(df_rawData70[key_col][i])
        uid_trainYes[uid] = 1
    
    num_rcds = len(df_rawData30[key_col])
    for i in range(num_rcds):
        uid = str(df_rawData30[key_col][i])
        uid_trainYes[uid] = 0
    return uid_trainYes
############3333
uid_trainYes = train_test_dict(df_rawData70, key_col)
print uid_trainYes.items()[0:3]
# Out:
# [('CC33ANGG46', 1), ('CCG420NGY9', 1), ('CCI9MI20N3', 1)]

# %%
dics = [ac_cat_colDic, eq_cat_colDic, ac_cnt_colDic, eq_cnt_colDic, ac_dateColDict, \
        eq_dateColDict, cu_dateColDict, cu_catColDict, cu_contColDict]

# %%
def integrate_cols(colDicts, uid_trainYes, key_col, uid_tag):
    pos_colDict = defaultdict(list)
    neg_colDict = defaultdict(list)
    
    uid_col_val = defaultdict(lambda:defaultdict(str))
    col_set = set()
    for k, colDict in enumerate(colDicts):
        #print k
        cols = [x for x in colDict.keys() if x != "apprefno"]
        col_set = col_set.union(cols)
        num_rcds = len(colDict[key_col])
        #print num_rcds
        for i in range(num_rcds):
            uid = colDict[key_col][i]
            for col in cols:
                val0 = colDict[col][i]
                try:
                    val = float(val0)
                except:
                    val == "-99"
                uid_col_val[uid][col] = str(val)
            #if i > 20:
            #    return None, None
    
    print "into_single colDict..."
    allColDict_train = defaultdict(list)
    allColDict_test = defaultdict(list)
    col_list = list(col_set)
    
    
    print col_list[0:10], "..."
    tr_uids = []
    ts_uids = []
    tr_posneg = []
    ts_posneg = []
    ct = 0
    skp_ct = 0
    print "number of uids to be processed", len(uid_trainYes.items())
    for uid, tag in uid_trainYes.items():
        if ct % 10000 == 0:
            print ct
        ct += 1
        if (uid not in uid_trainYes) or (uid not in uid_tag):
            skp_ct +=1
            continue
            
        pso_neg_tag = uid_tag[uid]
        if tag == 1:
            tr_uids.append(uid)
            tr_posneg.append(pso_neg_tag)
            for col in col_list:
                allColDict_train[col].append(uid_col_val[uid][col])
        else:
            ts_uids.append(uid)
            ts_posneg.append(pso_neg_tag)
            for col in col_list:
                allColDict_test[col].append(uid_col_val[uid][col])
    
    allColDict_train["userid"] = tr_uids
    allColDict_test["userid"] = ts_uids
    allColDict_train["PosNgTag"] = tr_posneg
    allColDict_test["PosNgTag"] = ts_posneg
    print "skipped:", skp_ct
    return allColDict_train, allColDict_test
################### test ##################33
allColDict_train, allColDict_test = integrate_cols(dics, uid_trainYes, "userid", id_tag)
# Out:
# into_single colDict...
# ['cur@#_worst_dpd6@#9', 'cur@#_se_code@#AS18', 'cur@#_year_joining', 'acc@#_actualpaymentamount_med', 'cur@#_worst_dpd6@#0', 'cur@#_se_code@#AS11', 'cur@#_app_office_state@#13.0', 'enq@#_upload_dt@#counts', 'cur@#_card_name@#Titanium Deligh', 'cur@#_app_state@#10.0'] ...
# number of uids to be processed 34136
# 0
# 10000
# 20000
# 30000
# skipped: 0

# %%
df_test = pd.DataFrame(allColDict_test)
df_train = pd.DataFrame(allColDict_train)

# %%
df_test.to_csv("./tranfered_data/test.csv")
df_train.to_csv("./tranfered_data/train.csv")

# %%
print cu_contColDict.keys()
# Out:
# ['cur@#_years_exp', 'cur@#_year_joining', 'cur@#_app_gross_monthly_income', 'cur@#_existing_credit_limit', 'cur@#_cibil_score', 'userid', 'cur@#_res_from_month', 'cur@#_num_dependents', 'cur@#_res_from_yr', 'cur@#_net_monthly_income']
